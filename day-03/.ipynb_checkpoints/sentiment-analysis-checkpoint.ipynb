# %%
# Import NLTK module and vader_lexicon module

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\24IT004\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Import SentimentIntensityAnalyzer from nltk.sentiment.vader

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()

# %%
# Print polarity score of a text - tone - part 1

# %%
a = "This is a good movie"
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.508, 'pos': 0.492, 'compound': 0.4404}

# %%
# Print polarity score of a text - tone - part 2

# %%
a = "I would like to know if there is extra chairs available or not . if so please let me have it"
sid.polarity_scores(a)
# Out:
# {'neg': 0.0, 'neu': 0.756, 'pos': 0.244, 'compound': 0.6696}

# %%
# Print polarity score of a text - tone - part 3

# %%
a = "I hate apples"
sid.polarity_scores(a)
# Out:
# {'neg': 0.787, 'neu': 0.213, 'pos': 0.0, 'compound': -0.5719}

# %%
# Import pandas and numpy modules

# %%
import pandas as pd
import numpy as np

# %%
# Load file to dataframe and print head of file

# %%
df = pd.read_csv("amazonreviews.tsv",sep='\t')
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv("amazonreviews.tsv",sep='\t')
#       2 df.head()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# Finds and removes rows where a column contains only blank spaces, then shows how many samples each label has

# %%
blanks = []
for i,lb,rv in df.itertuples():
    if(type(rv)==str):
        if(rv.isspace()):
            blanks.append(i)

df.drop(blanks,inplace=True)
df['label'].value_counts()

# %%
sid.polarity_scores(df.loc[0]['review'])
df.loc[0]['label']

# %%
df['scores'] = df['review'].apply(lambda review:sid.polarity_scores(review))

df.head()

# %%
df['compound'] = df['scores'].apply(lambda scoredict:scoredict['compound'])
df.head()

# %%
sid.polarity_scores(df.loc[0]['review'])
df.loc[0]['scores']

# %%
df['compscore'] = df['compound'].apply(lambda c:'pos'if c>=0 else 'neg')
df.head()

# %%
from sklearn.metrics import *

print(df['label'].value_counts())
accuracy_score(df['label'],df['compscore'])

# %%
print(confusion_matrix(df['label'],df['compscore']))

# %%
print(classification_report(df['label'],df['compscore']))
