# %%
# Import spacy

# %%
import spacy

# %%
# Download the language model

# %%
# !python -m spacy download en_core_web_md
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/33.5 MB ? eta -:--:--
#      ---------------------------------------- 0.0/33.5 MB ? eta -:--:--
#      --- ------------------------------------ 2.6/33.5 MB 15.1 MB/s eta 0:00:03
#      ------- -------------------------------- 6.3/33.5 MB 17.2 MB/s eta 0:00:02
#      ----------- --------------------------- 10.2/33.5 MB 17.4 MB/s eta 0:00:02
#      ------------------- ------------------- 16.5/33.5 MB 20.5 MB/s eta 0:00:01
#      -------------------------- ------------ 22.8/33.5 MB 22.6 MB/s eta 0:00:01
#      -------------------------------- ------ 27.8/33.5 MB 23.0 MB/s eta 0:00:01
#      ------------------------------------- - 32.5/33.5 MB 23.0 MB/s eta 0:00:01
#      ---------------------------------------- 33.5/33.5 MB 21.9 MB/s  0:00:01
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
# Load the language model into the NLP

# %%
nlp = spacy.load('en_core_web_md')
