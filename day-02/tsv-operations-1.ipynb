# %%
# Import pandas and numpy libraries

# %%
import pandas as pd
import numpy as np

# %%
# Create a dataframe for a .tsv file

# %%
df = pd.read_csv(r"C:/Users/yashm/Downloads/moviereviews.tsv", sep = "\t")

# %%
# Print the head of the dataframe - top preview of dataset - 5 rows

# %%
print(df.head())
# Out:
#   label                                             review
# 0   neg  how do films like mouse hunt get into theatres...
# 1   neg  some talented actresses are blessed with a dem...
# 2   pos  this has been an extraordinary year for austra...
# 3   pos  according to hollywood movies made in last few...
# 4   neg  my first press screening of 1998 and already i...

# %%
# To find the length of dataframe

# %%
len(df)
# Out:
# 2000

# %%
# To count missing values in each column

# %%
df.isnull().sum()
# Out:
# label      0
# review    35
# dtype: int64

# %%
# To list out all columns in the dataframe

# %%
df.columns
# Out:
# Index(['label', 'review'], dtype='object')

# %%
# To describe a column

# %%
df['label'].describe()
# Out:
# count     2000
# unique       2
# top        neg
# freq      1000
# Name: label, dtype: object

# %%
# To list out the unique values of column

# %%
df['label'].unique()
# Out:
# array(['neg', 'pos'], dtype=object)

# %%
# To print the value count of column

# %%
df['label'].value_counts()
# Out:
# label
# neg    1000
# pos    1000
# Name: count, dtype: int64

# %%
# Import plt from matplotlib.plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# To draw a histogram

# %%
plt.xscale('log')
bins = 1.15 ** (np.arange(0, 50))

plt.hist(df[df['label'] == 'ham']['review'], bins=bins, alpha=0.8)
plt.hist(df[df['label'] == 'spam']['review'], bins=bins, alpha=0.8)

plt.legend(('ham', 'spam'))
plt.show()

# %%
# !pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\yashm\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.0.0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 1.5 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/8.0 MB 1.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.0 MB 1.7 MB/s eta 0:00:05
#    ------- -------------------------------- 1.6/8.0 MB 1.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.0 MB 1.8 MB/s eta 0:00:04
#    -------------- ------------------------- 2.9/8.0 MB 2.0 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.0 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.0 MB 2.0 MB/s eta 0:00:03
#    -------------------- ------------------- 4.2/8.0 MB 2.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 4.5/8.0 MB 2.2 MB/s eta 0:00:02
#    -------------------------- ------------- 5.2/8.0 MB 2.2 MB/s eta 0:00:02
#    -------------------------------- ------- 6.6/8.0 MB 2.5 MB/s eta 0:00:01
#    ------------------------------------ --- 7.3/8.0 MB 2.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.6/8.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 2.5 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp312-cp312-win_amd64.whl (36.5 MB)
#    ---------------------------------------- 0.0/36.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.5 MB 4.8 MB/s eta 0:00:08
#    - -------------------------------------- 1.3/36.5 MB 3.2 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/36.5 MB 3.2 MB/s eta 0:00:12
#    -- ------------------------------------- 1.8/36.5 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 2.1/36.5 MB 2.0 MB/s eta 0:00:18
#    -- ------------------------------------- 2.6/36.5 MB 2.1 MB/s eta 0:00:17
#    ---- ----------------------------------- 3.7/36.5 MB 2.4 MB/s eta 0:00:14
#    ---- ----------------------------------- 4.5/36.5 MB 2.6 MB/s eta 0:00:13
#    ----- ---------------------------------- 5.2/36.5 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 5.5/36.5 MB 2.6 MB/s eta 0:00:12
#    ------ --------------------------------- 6.3/36.5 MB 2.7 MB/s eta 0:00:12
#    -------- ------------------------------- 7.6/36.5 MB 3.0 MB/s eta 0:00:10
#    --------- ------------------------------ 8.7/36.5 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 9.4/36.5 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 9.4/36.5 MB 3.2 MB/s eta 0:00:09
#    ---------- ----------------------------- 9.7/36.5 MB 2.9 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/36.5 MB 2.8 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/36.5 MB 2.8 MB/s eta 0:00:10
#    ----------- ---------------------------- 10.5/36.5 MB 2.6 MB/s eta 0:00:11
#    ------------ --------------------------- 11.3/36.5 MB 2.7 MB/s eta 0:00:10
#    ------------- -------------------------- 12.6/36.5 MB 2.8 MB/s eta 0:00:09
#    -------------- ------------------------- 13.6/36.5 MB 2.9 MB/s eta 0:00:08
#    ---------------- ----------------------- 14.9/36.5 MB 3.0 MB/s eta 0:00:08
#    ----------------- ---------------------- 16.0/36.5 MB 3.1 MB/s eta 0:00:07
#    ------------------ --------------------- 17.0/36.5 MB 3.2 MB/s eta 0:00:07
#    -------------------- ------------------- 18.6/36.5 MB 3.3 MB/s eta 0:00:06
#    --------------------- ------------------ 19.7/36.5 MB 3.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 21.0/36.5 MB 3.5 MB/s eta 0:00:05
#    ----------------------- ---------------- 21.8/36.5 MB 3.5 MB/s eta 0:00:05
#    ------------------------- -------------- 23.1/36.5 MB 3.6 MB/s eta 0:00:04
#    -------------------------- ------------- 24.4/36.5 MB 3.7 MB/s eta 0:00:04
#    --------------------------- ------------ 25.4/36.5 MB 3.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 26.5/36.5 MB 3.8 MB/s eta 0:00:03
#    ------------------------------ --------- 28.0/36.5 MB 3.9 MB/s eta 0:00:03
#    ------------------------------- -------- 29.1/36.5 MB 3.9 MB/s eta 0:00:02
#    --------------------------------- ------ 30.4/36.5 MB 4.0 MB/s eta 0:00:02
#    ---------------------------------- ----- 31.2/36.5 MB 4.0 MB/s eta 0:00:02
#    ----------------------------------- ---- 32.5/36.5 MB 4.0 MB/s eta 0:00:02
#    ------------------------------------- -- 33.8/36.5 MB 4.1 MB/s eta 0:00:01
#    ------------------------------------- -- 34.6/36.5 MB 4.1 MB/s eta 0:00:01
#    -------------------------------------- - 35.4/36.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------  35.9/36.5 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 36.5/36.5 MB 4.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: C:\Users\yashm\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split
X = df[['label','label']]
y=df['label']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.33,random_state=42)


print("Training Data Shape: ", X_train.shape)
print("Training Data Shape: ", X_test.shape)
# Out:
# Training Data Shape:  (1340, 2)
# Training Data Shape:  (660, 2)
